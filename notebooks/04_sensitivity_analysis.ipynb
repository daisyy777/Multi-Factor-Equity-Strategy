# %% [markdown]
# # Sensitivity Analysis
#
# This notebook explores how strategy performance varies with different parameter settings.
#
# ## Objectives
# 1. Test different factor weights
# 2. Analyze impact of rebalancing frequency
# 3. Examine effect of long/short percentiles
# 4. Study transaction cost sensitivity

# %%
import sys
from pathlib import Path

# Add src to path
project_root = Path().resolve().parent.parent
sys.path.insert(0, str(project_root))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.utils.config import BACKTEST_CONFIG, FACTOR_CONFIG

# This notebook is a template for sensitivity analysis
# You can modify parameters and re-run backtests to see their impact

print("Sensitivity Analysis Template")
print("=" * 60)
print("\nKey parameters to vary:")
print("  1. Factor weights (equal vs regression-based)")
print("  2. Rebalancing frequency (monthly vs quarterly)")
print("  3. Long/short percentiles (e.g., 10% vs 20% vs 30%)")
print("  4. Transaction costs (commission + slippage)")
print("  5. Maximum position size")
print("\nModify these in src/utils/config.py and re-run backtests to compare results.")
